# %%
from HPC_python_library.plotters import *

# %% [markdown]
# Plot the density obtained through gaussian against the analytical solution

# %%
def E_dos_1D_analytical(x):
    return 1/(np.pi*(4-x**2)**0.5)

plot_range = np.arange(-1.99, 2, 0.01)
plt.plot(plot_range, E_dos_1D_analytical(plot_range), color="r")
plotter_not_CVS("./L3/Energy density")

# %% [markdown]
# ## 1.1.1 and 1.1.2

# %%
#%matplotlib qt

plotter_slider("./L3/Energy_density_PBC")
plotter_slider("./L3/Energy_density_OBC")

# %% [markdown]
# ## 1.1.3 (and 1.1.4)

# %%
plotter_colormap_not_CSV("./L3/n_evolution")

# %% [markdown]
# ## 1.1.5

# %%
plotter_colormap("./L5/1D_Efield_gaussian_evolution")

# %% [markdown]
# ## 1.1.6

# %%
# %matplotlib inline
plotter("./L6/exercise_6_data/BN_DOS")

# %%
benchmark_plotter("L6/exercise_6_data", "BN_benchmark", "DOS computation")
benchmark_plotter("L6/exercise_6_data", "BN_benchmark_improved", "DOS computation")

# %% [markdown]
# ## 1.1.7

# %%
plotter("./L6/exercise_7_data/BN_twisted_DOS")

# %%
plotter("./L7/exercise_8_data/anderson_twisted_DOS")
